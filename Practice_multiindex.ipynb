# %%
import pandas as pd
# %matplotlib inline

# %%
stocks = pd.read_excel('互联网公司股票.xlsx')

# %%
stocks
# Out:
#             日期    公司      收盘      开盘       高       低    交易量   涨跌幅
# 0   2019-10-03  BIDU  104.32  102.35  104.73  101.15   2.24  0.02
# 1   2019-10-02  BIDU  102.62  100.85  103.24   99.50   2.69  0.01
# 2   2019-10-01  BIDU  102.00  102.80  103.26  101.00   1.78 -0.01
# 3   2019-10-03  BABA  169.48  166.65  170.18  165.00  10.39  0.02
# 4   2019-10-02  BABA  165.77  162.82  166.88  161.90  11.60  0.00
# 5   2019-10-01  BABA  165.15  168.01  168.23  163.64  14.19 -0.01
# 6   2019-10-03    IQ   16.06   15.71   16.38   15.32  10.08  0.02
# 7   2019-10-02    IQ   15.72   15.85   15.87   15.12   8.10 -0.01
# 8   2019-10-01    IQ   15.92   16.14   16.22   15.50  11.65 -0.01
# 9   2019-10-03    JD   28.80   28.11   28.97   27.82   8.77  0.03
# 10  2019-10-02    JD   28.06   28.00   28.22   27.53   9.53  0.00
# 11  2019-10-01    JD   28.19   28.22   28.57   27.97  10.64  0.00

# %%
stocks.shape
# Out:
# (12, 8)

# %%
stocks.head(3)
# Out:
#            日期    公司      收盘      开盘       高       低   交易量   涨跌幅
# 0  2019-10-03  BIDU  104.32  102.35  104.73  101.15  2.24  0.02
# 1  2019-10-02  BIDU  102.62  100.85  103.24   99.50  2.69  0.01
# 2  2019-10-01  BIDU  102.00  102.80  103.26  101.00  1.78 -0.01

# %%
stocks['公司'].unique()
# Out:
# array(['BIDU', 'BABA', 'IQ', 'JD'], dtype=object)

# %%
stocks.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
stocks.groupby('公司')['开盘'].mean()
# Out:
# 公司
# BABA    165.826667
# BIDU    102.000000
# IQ       15.900000
# JD       28.110000
# Name: 开盘, dtype: float64

# %%
# MultiIndex
ser = stocks.groupby(['公司', '日期'])['收盘'].mean()
ser
# Out:
# 公司    日期
# BABA  2019-10-01    165.15
#       2019-10-02    165.77
#       2019-10-03    169.48
# BIDU  2019-10-01    102.00
#       2019-10-02    102.62
#       2019-10-03    104.32
# IQ    2019-10-01     15.92
#       2019-10-02     15.72
#       2019-10-03     16.06
# JD    2019-10-01     28.19
#       2019-10-02     28.06
#       2019-10-03     28.80
# Name: 收盘, dtype: float64

# %%
ser.index
# Out:
# MultiIndex([('BABA', '2019-10-01'),
#             ('BABA', '2019-10-02'),
#             ('BABA', '2019-10-03'),
#             ('BIDU', '2019-10-01'),
#             ('BIDU', '2019-10-02'),
#             ('BIDU', '2019-10-03'),
#             (  'IQ', '2019-10-01'),
#             (  'IQ', '2019-10-02'),
#             (  'IQ', '2019-10-03'),
#             (  'JD', '2019-10-01'),
#             (  'JD', '2019-10-02'),
#             (  'JD', '2019-10-03')],
#            names=['公司', '日期'])

# %%
# unstack is to make second index to row
ser.unstack()
# Out:
# 日期    2019-10-01  2019-10-02  2019-10-03
# 公司
# BABA      165.15      165.77      169.48
# BIDU      102.00      102.62      104.32
# IQ         15.92       15.72       16.06
# JD         28.19       28.06       28.80

# %%
ser.reset_index()
# Out:
#       公司          日期      收盘
# 0   BABA  2019-10-01  165.15
# 1   BABA  2019-10-02  165.77
# 2   BABA  2019-10-03  169.48
# 3   BIDU  2019-10-01  102.00
# 4   BIDU  2019-10-02  102.62
# 5   BIDU  2019-10-03  104.32
# 6     IQ  2019-10-01   15.92
# 7     IQ  2019-10-02   15.72
# 8     IQ  2019-10-03   16.06
# 9     JD  2019-10-01   28.19
# 10    JD  2019-10-02   28.06
# 11    JD  2019-10-03   28.80

# %%
ser
# Out:
# 公司    日期
# BABA  2019-10-01    165.15
#       2019-10-02    165.77
#       2019-10-03    169.48
# BIDU  2019-10-01    102.00
#       2019-10-02    102.62
#       2019-10-03    104.32
# IQ    2019-10-01     15.92
#       2019-10-02     15.72
#       2019-10-03     16.06
# JD    2019-10-01     28.19
#       2019-10-02     28.06
#       2019-10-03     28.80
# Name: 收盘, dtype: float64

# %%
ser.loc['BIDU']
# Out:
# 日期
# 2019-10-01    102.00
# 2019-10-02    102.62
# 2019-10-03    104.32
# Name: 收盘, dtype: float64

# %%
ser.loc[('BIDU', '2019-10-02')]
# Out:
# 102.62

# %%
ser.loc[:, '2019-10-02']
# Out:
# 公司
# BABA    165.77
# BIDU    102.62
# IQ       15.72
# JD       28.06
# Name: 收盘, dtype: float64

# %%
stocks
# Out:
#             日期    公司      收盘      开盘       高       低    交易量   涨跌幅
# 0   2019-10-03  BIDU  104.32  102.35  104.73  101.15   2.24  0.02
# 1   2019-10-02  BIDU  102.62  100.85  103.24   99.50   2.69  0.01
# 2   2019-10-01  BIDU  102.00  102.80  103.26  101.00   1.78 -0.01
# 3   2019-10-03  BABA  169.48  166.65  170.18  165.00  10.39  0.02
# 4   2019-10-02  BABA  165.77  162.82  166.88  161.90  11.60  0.00
# 5   2019-10-01  BABA  165.15  168.01  168.23  163.64  14.19 -0.01
# 6   2019-10-03    IQ   16.06   15.71   16.38   15.32  10.08  0.02
# 7   2019-10-02    IQ   15.72   15.85   15.87   15.12   8.10 -0.01
# 8   2019-10-01    IQ   15.92   16.14   16.22   15.50  11.65 -0.01
# 9   2019-10-03    JD   28.80   28.11   28.97   27.82   8.77  0.03
# 10  2019-10-02    JD   28.06   28.00   28.22   27.53   9.53  0.00
# 11  2019-10-01    JD   28.19   28.22   28.57   27.97  10.64  0.00

# %%
stocks.sort_index(inplace=True)
stocks
# Out:
#             日期    公司      收盘      开盘       高       低    交易量   涨跌幅
# 0   2019-10-03  BIDU  104.32  102.35  104.73  101.15   2.24  0.02
# 1   2019-10-02  BIDU  102.62  100.85  103.24   99.50   2.69  0.01
# 2   2019-10-01  BIDU  102.00  102.80  103.26  101.00   1.78 -0.01
# 3   2019-10-03  BABA  169.48  166.65  170.18  165.00  10.39  0.02
# 4   2019-10-02  BABA  165.77  162.82  166.88  161.90  11.60  0.00
# 5   2019-10-01  BABA  165.15  168.01  168.23  163.64  14.19 -0.01
# 6   2019-10-03    IQ   16.06   15.71   16.38   15.32  10.08  0.02
# 7   2019-10-02    IQ   15.72   15.85   15.87   15.12   8.10 -0.01
# 8   2019-10-01    IQ   15.92   16.14   16.22   15.50  11.65 -0.01
# 9   2019-10-03    JD   28.80   28.11   28.97   27.82   8.77  0.03
# 10  2019-10-02    JD   28.06   28.00   28.22   27.53   9.53  0.00
# 11  2019-10-01    JD   28.19   28.22   28.57   27.97  10.64  0.00

# %%
stocks
# Out:
#             日期    公司      收盘      开盘       高       低    交易量   涨跌幅
# 0   2019-10-03  BIDU  104.32  102.35  104.73  101.15   2.24  0.02
# 1   2019-10-02  BIDU  102.62  100.85  103.24   99.50   2.69  0.01
# 2   2019-10-01  BIDU  102.00  102.80  103.26  101.00   1.78 -0.01
# 3   2019-10-03  BABA  169.48  166.65  170.18  165.00  10.39  0.02
# 4   2019-10-02  BABA  165.77  162.82  166.88  161.90  11.60  0.00
# 5   2019-10-01  BABA  165.15  168.01  168.23  163.64  14.19 -0.01
# 6   2019-10-03    IQ   16.06   15.71   16.38   15.32  10.08  0.02
# 7   2019-10-02    IQ   15.72   15.85   15.87   15.12   8.10 -0.01
# 8   2019-10-01    IQ   15.92   16.14   16.22   15.50  11.65 -0.01
# 9   2019-10-03    JD   28.80   28.11   28.97   27.82   8.77  0.03
# 10  2019-10-02    JD   28.06   28.00   28.22   27.53   9.53  0.00
# 11  2019-10-01    JD   28.19   28.22   28.57   27.97  10.64  0.00

# %%
stocks.loc['BIDU']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23636/3917759324.py in <module>
# ----> 1 stocks.loc['BIDU']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
# ...

# %%
stocks.loc[('BIDU', '2019-10-02'), :]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23636/734750060.py in <module>
# ----> 1 stocks.loc[('BIDU', '2019-10-02'), :]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
stocks.loc[('BIDU', '2019-10-02'), '收盘']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23636/3731685516.py in <module>
# ----> 1 stocks.loc[('BIDU', '2019-10-02'), '收盘']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
stocks.loc[['BIDU', 'JD'], :]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23636/1304166979.py in <module>
# ----> 1 stocks.loc[['BIDU', 'JD'], :]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
stocks.loc[(['BIDU', 'JD'], '2019-10-03'), :]
# Out:
# C:\Users\yzeng\anaconda3\lib\site-packages\numpy\core\_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23636/426818343.py in <module>
# ----> 1 stocks.loc[(['BIDU', 'JD'], '2019-10-03'), :]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
# ...

# %%
stocks.loc[(slice(None), ['2019-10-02', '2019-10-03']), :]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23636/2706903683.py in <module>
# ----> 1 stocks.loc[(slice(None), ['2019-10-02', '2019-10-03']), :]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# ...

# %%
stocks.reset_index()
# Out:
#     index          日期    公司      收盘      开盘       高       低    交易量   涨跌幅
# 0       0  2019-10-03  BIDU  104.32  102.35  104.73  101.15   2.24  0.02
# 1       1  2019-10-02  BIDU  102.62  100.85  103.24   99.50   2.69  0.01
# 2       2  2019-10-01  BIDU  102.00  102.80  103.26  101.00   1.78 -0.01
# 3       3  2019-10-03  BABA  169.48  166.65  170.18  165.00  10.39  0.02
# 4       4  2019-10-02  BABA  165.77  162.82  166.88  161.90  11.60  0.00
# 5       5  2019-10-01  BABA  165.15  168.01  168.23  163.64  14.19 -0.01
# 6       6  2019-10-03    IQ   16.06   15.71   16.38   15.32  10.08  0.02
# 7       7  2019-10-02    IQ   15.72   15.85   15.87   15.12   8.10 -0.01
# 8       8  2019-10-01    IQ   15.92   16.14   16.22   15.50  11.65 -0.01
# 9       9  2019-10-03    JD   28.80   28.11   28.97   27.82   8.77  0.03
# 10     10  2019-10-02    JD   28.06   28.00   28.22   27.53   9.53  0.00
# 11     11  2019-10-01    JD   28.19   28.22   28.57   27.97  10.64  0.00
