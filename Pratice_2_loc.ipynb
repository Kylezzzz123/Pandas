# %%
import pandas as pd

# %%
df = pd.read_csv('beijing_tianqi_2018.csv')

# %%
df
# Out:
#             ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0    2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1    2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2    2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3    2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4    2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
# ..          ...    ...    ...    ...       ...    ...  ...     ...       ...
# 360  2018-12-27    -5℃   -12℃   多云~晴       西北风     3级   48       优         1
# 361  2018-12-28    -3℃   -11℃      晴       西北风     3级   40       优         1
# 362  2018-12-29    -3℃   -12℃      晴       西北风     2级   29       优         1
# 363  2018-12-30    -2℃   -11℃   晴~多云       东北风     1级   31       优         1
# 364  2018-12-31    -2℃   -10℃     多云       东北风     1级   56       良         2
#
# [365 rows x 9 columns]

# %%
df.head()   # read first 5 rows
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1

# %%
df.index
# Out:
# RangeIndex(start=0, stop=365, step=1)

# %%
df.loc[:,'bWendu'] = df['bWendu'].str.replace("℃", "").astype('int32')
df.loc[:,'yWendu'] = df['yWendu'].str.replace("℃", "").astype('int32')

# %%
df.dtypes
# Out:
# ymd          object
# bWendu        int32
# yWendu        int32
# tianqi       object
# fengxiang    object
# fengli       object
# aqi           int64
# aqiInfo      object
# aqiLevel      int64
# dtype: object

# %%
df.head()
# Out:
#           ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2018-01-01       3      -6   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03       2      -5     多云        北风   1-2级   28       优         1
# 3  2018-01-04       0      -8      阴       东北风   1-2级   28       优         1
# 4  2018-01-05       3      -6   多云~晴       西北风   1-2级   50       优         1

# %%
df.loc[1:2]
# Out:
#           ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 1  2018-01-02       2      -5   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03       2      -5     多云        北风   1-2级   28       优         1

# %%
df.set_index('ymd', inplace=True)

# %%
df.loc['2018-01-02']
# Out:
# bWendu          2
# yWendu         -5
# tianqi       阴~多云
# fengxiang     东北风
# fengli       1-2级
# aqi            49
# aqiInfo         优
# aqiLevel        1
# Name: 2018-01-02, dtype: object

# %%
df.loc[['2018-01-02', '2018-01-05', '2018-01-03'], ['bWendu', 'yWendu']]
# Out:
#             bWendu  yWendu
# ymd
# 2018-01-02       2      -5
# 2018-01-05       3      -6
# 2018-01-03       2      -5

# %%
df.loc['2018-01-03': '2018-01-05', 'bWendu']
# Out:
# ymd
# 2018-01-03    2
# 2018-01-04    0
# 2018-01-05    3
# Name: bWendu, dtype: int32

# %%
df.loc[[], ['bWendu']]
# Out:
# Empty DataFrame
# Columns: [bWendu]
# Index: []

# %%
df.loc[df['yWendu']<-10, :]   # rows and then column (:)  --> boolen
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-23      -4     -12      晴       西北风   3-4级   31       优         1
# 2018-01-24      -4     -11      晴       西南风   1-2级   34       优         1
# 2018-01-25      -3     -11     多云       东北风   1-2级   27       优         1
# 2018-12-26      -2     -11   晴~多云       东北风     2级   26       优         1
# 2018-12-27      -5     -12   多云~晴       西北风     3级   48       优         1
# 2018-12-28      -3     -11      晴       西北风     3级   40       优         1
# 2018-12-29      -3     -12      晴       西北风     2级   29       优         1
# 2018-12-30      -2     -11   晴~多云       东北风     1级   31       优         1

# %%
df.loc[(df['bWendu']<=30) & (df['yWendu']>=15) & (df['aqiLevel']==1) & (df['tianqi']=='晴'), :]
# Out:
#             ymd  bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 235  2018-08-24      30      20      晴        北风   1-2级   40       优         1
# 249  2018-09-07      27      16      晴       西北风   3-4级   22       优         1

# %%
df.loc[lambda df : (df['bWendu']<=30) & (df['yWendu']>=15), :]
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-04-28      27      17      晴       西南风   3-4级  125    轻度污染         3
# 2018-04-29      30      16     多云        南风   3-4级  193    中度污染         4
# 2018-05-04      27      16   晴~多云       西南风   1-2级   86       良         2
# 2018-05-09      29      17   晴~多云       西南风   3-4级   79       良         2
# 2018-05-10      26      18     多云        南风   3-4级  118    轻度污染         3
# ...            ...     ...    ...       ...    ...  ...     ...       ...
# 2018-09-15      26      15     多云        北风   3-4级   42       优         1
# 2018-09-17      27      17   多云~阴        北风   1-2级   37       优         1
# 2018-09-18      25      17   阴~多云       西南风   1-2级   50       优         1
# 2018-09-19      26      17     多云        南风   1-2级   52       良         2
# 2018-09-20      27      16     多云       西南风   1-2级   63       良         2
#
# [64 rows x 8 columns]

# %%
df.loc[(df['bWendu']<=30) & (df['yWendu']>=15), :]
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-04-28      27      17      晴       西南风   3-4级  125    轻度污染         3
# 2018-04-29      30      16     多云        南风   3-4级  193    中度污染         4
# 2018-05-04      27      16   晴~多云       西南风   1-2级   86       良         2
# 2018-05-09      29      17   晴~多云       西南风   3-4级   79       良         2
# 2018-05-10      26      18     多云        南风   3-4级  118    轻度污染         3
# ...            ...     ...    ...       ...    ...  ...     ...       ...
# 2018-09-15      26      15     多云        北风   3-4级   42       优         1
# 2018-09-17      27      17   多云~阴        北风   1-2级   37       优         1
# 2018-09-18      25      17   阴~多云       西南风   1-2级   50       优         1
# 2018-09-19      26      17     多云        南风   1-2级   52       良         2
# 2018-09-20      27      16     多云       西南风   1-2级   63       良         2
#
# [64 rows x 8 columns]

# %%
a = df.loc[df['tianqi']=='多云', :]

# %%
a.head(10)
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-01-03       2      -5     多云        北风   1-2级   28       优         1
# 2018-01-13       3      -7     多云        南风   1-2级  126    轻度污染         3
# 2018-01-16       4      -5     多云        南风   1-2级  112    轻度污染         3
# 2018-01-25      -3     -11     多云       东北风   1-2级   27       优         1
# 2018-01-27      -1      -9     多云        南风   1-2级  105    轻度污染         3
# 2018-02-01       4      -7     多云        北风   1-2级   68       良         2
# 2018-02-03       0      -9     多云        北风   1-2级   24       优         1
# 2018-02-08       3      -7     多云        南风   3-4级   67       良         2
# 2018-02-09       4      -9     多云       西北风   4-5级   93       良         2
# 2018-02-14       6      -6     多云        北风   1-2级   42       优         1

# %%
b = df.index.str.startswith('2018-09')   # pick 2018-09 data
df.loc[b,:]   # select 2018-09 data, : for all columns
# Out:
#             bWendu  yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# ymd
# 2018-09-01      27      19   阴~小雨        南风   1-2级   50       优         1
# 2018-09-02      27      19  小雨~多云        南风   1-2级   55       良         2
# 2018-09-03      30      19      晴        北风   3-4级   70       良         2
# 2018-09-04      31      18      晴       西南风   3-4级   24       优         1
# 2018-09-05      31      19   晴~多云       西南风   3-4级   34       优         1
# 2018-09-06      27      18   多云~晴       西北风   4-5级   37       优         1
# 2018-09-07      27      16      晴       西北风   3-4级   22       优         1
# 2018-09-08      27      15   多云~晴        北风   1-2级   28       优         1
# 2018-09-09      28      16      晴       西南风   1-2级   51       良         2
# 2018-09-10      28      19     多云        南风   1-2级   65       良         2
# 2018-09-11      26      19     多云        南风   1-2级   68       良         2
# 2018-09-12      29      19     多云        南风   1-2级   59       良         2
# ...

# %%
df['bWendu']
# Out:
# 0      3
# 1      2
# 2      2
# 3      0
# 4      3
#       ..
# 360   -5
# 361   -3
# 362   -3
# 363   -2
# 364   -2
# Name: bWendu, Length: 365, dtype: int32

# %%
df[['ymd','aqiInfo']]
# Out:
#             ymd aqiInfo
# 0    2018-01-01       良
# 1    2018-01-02       优
# 2    2018-01-03       优
# 3    2018-01-04       优
# 4    2018-01-05       优
# ..          ...     ...
# 360  2018-12-27       优
# 361  2018-12-28       优
# 362  2018-12-29       优
# 363  2018-12-30       优
# 364  2018-12-31       良
#
# [365 rows x 2 columns]
